# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ![resident.png](data:image/png;base64,...)

# %%
a = 3 * 320.52
print(a)

b = 834.47/ 119.21
print(int(b))

c = 15378.12 / 5
print(round(c,2))
# Out:
# 961.56
# 7
# 3075.62

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião'

cancao_maiuscula = cancao.upper()
print(cancao_maiuscula)

print(len(cancao))

divisor_verso = cancao.find(',')
primeiro_verso = cancao[0:divisor_verso]
print(primeiro_verso)
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO
# 48
# Roda mundo

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

selic = noticia[12:17]
print(selic)

ano = noticia.find('6')
print(ano)

ano = noticia[62]
print(ano)
# Out:
# 2,75%
# 62
# 6

# %%
a = False
b = True

x = not a & b

print(x)
# Out:
# True
